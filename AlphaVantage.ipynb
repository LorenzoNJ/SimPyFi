# %%
# not so good in term of speed
# no available paralellisation
# worst API ever : returns a json

# %%
import pandas as pd
import numpy as np
from alpha_vantage.timeseries import TimeSeries
key = 'E2S9WCQXMIMBMR61' #E2S9WCQXMIMBMR61 is the real key

#for in depth only
from alpha_vantage.techindicators import TechIndicators
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
# On charge le dataset
stock_list = pd.read_csv('data_finance/stocks.csv')['Stock_Name'].tolist()
index_list = pd.read_csv('data_finance/index.csv')['Index_Symbol'].tolist()

# %%
ts = TimeSeries(key)
aapl, meta = ts.get_daily(symbol='AAPL')
df = pd.DataFrame(aapl).astype(float).transpose()

# %%
df['4. close'].plot()

# %%
'''
On your terminal run:
pip install alpha_vantage
This also uses the pandas dataframe, and matplotlib, commonly used python packages
pip install pandas
pip install matplotlib
For the develop version run:
pip install git+https://github.com/RomelTorres/alpha_vantage.git@develop
'''



# Your key here
# Chose your output format, or default to JSON (python dict)
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# Get the data, returns a tuple
# aapl_data is a pandas dataframe, aapl_meta_data is a dict
aapl_data, aapl_meta_data = ts.get_daily(symbol='AAPL')
# aapl_sma is a dict, aapl_meta_sma also a dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol='AAPL')


# Visualization
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
aapl_data['4. close'].plot()
plt.tight_layout()
plt.grid()
plt.show()

# %%
df['4. close'].plot()

# %%
aapl_sma
# Out:
# {'2020-04-13': {'SMA': '250.2135'},
#  '2020-04-09': {'SMA': '250.4495'},
#  '2020-04-08': {'SMA': '249.4615'},
#  '2020-04-07': {'SMA': '249.9295'},
#  '2020-04-06': {'SMA': '251.2250'},
#  '2020-04-03': {'SMA': '251.4100'},
#  '2020-04-02': {'SMA': '253.7910'},
#  '2020-04-01': {'SMA': '256.1905'},
#  '2020-03-31': {'SMA': '259.2820'},
#  '2020-03-30': {'SMA': '261.0335'},
#  '2020-03-27': {'SMA': '263.2335'},
#  '2020-03-26': {'SMA': '264.5145'},
#  '2020-03-25': {'SMA': '265.2685'},
#  '2020-03-24': {'SMA': '267.6250'},
#  '2020-03-23': {'SMA': '269.6850'},
#  '2020-03-20': {'SMA': '273.3755'},
#  '2020-03-19': {'SMA': '277.5660'},
#  '2020-03-18': {'SMA': '281.3420'},
#  '2020-03-17': {'SMA': '285.1895'},
#  '2020-03-16': {'SMA': '288.4965'},
#  '2020-03-13': {'SMA': '292.6335'},
#  '2020-03-12': {'SMA': '294.9785'},
#  '2020-03-11': {'SMA': '298.9270'},
#  '2020-03-10': {'SMA': '301.1360'},
#  '2020-03-09': {'SMA': '302.9465'},
#  '2020-03-06': {'SMA': '305.6395'},
# ...
